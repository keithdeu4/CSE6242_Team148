# %%
import requests
import random
import string
import pandas as pd
import requests
import base64

# Spotify API credentials (replace these with your actual credentials)
client_id = ''
client_secret = ''

# Step 1: Encode Client ID and Client Secret
def get_access_token(client_id, client_secret):
    # Base64 encode client_id and client_secret
    client_creds = f"{client_id}:{client_secret}"
    client_creds_b64 = base64.b64encode(client_creds.encode())

    # Step 2: Request access token
    token_url = 'https://accounts.spotify.com/api/token'
    headers = {
        'Authorization': f'Basic {client_creds_b64.decode()}',
    }
    data = {
        'grant_type': 'client_credentials',
    }

    r = requests.post(token_url, headers=headers, data=data)
    if r.status_code == 200:
        token = r.json()['access_token']
        return token
    else:
        raise Exception("Failed to get access token", r.status_code, r.text)

# Get the access token
access_token = get_access_token(client_id, client_secret)

# Function to generate random search queries
def get_random_query():
    # Generate a random letter or string to search for
    return random.choice(string.ascii_lowercase)

# Function to search for random tracks
def search_random_tracks(access_token, query, limit=10):
    url = "https://api.spotify.com/v1/search"
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    params = {
        'q': query,
        'type': 'track',
        'limit': limit  # Max limit per request is 50
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 200:
        return response.json()['tracks']['items']  # List of track items
    else:
        print(f"Error searching tracks: {response.status_code} - {response.text}")
        return None

# Function to get track metadata
def get_track_data(track_id, access_token):
    url = f"https://api.spotify.com/v1/tracks/{track_id}"
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching track data: {response.status_code} - {response.text}")
        return None

# Function to get audio features
def get_audio_features(track_id, access_token):
    url = f"https://api.spotify.com/v1/audio-features/{track_id}"
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching audio features: {response.status_code} - {response.text}")
        return None

# Function to get artist genres
def get_artist_genres(artist_id, access_token):
    url = f"https://api.spotify.com/v1/artists/{artist_id}"
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json().get('genres', [])
    else:
        print(f"Error fetching artist genres: {response.status_code} - {response.text}")
        return None

# Function to combine track metadata and audio features
def get_combined_data(track, access_token):
    track_id = track['id']
    audio_features = get_audio_features(track_id, access_token)
    
    if audio_features:
        # Get artist info for genre
        artist_id = track['artists'][0]['id']  # Use the first artist 
        genres = get_artist_genres(artist_id, access_token)
        
        # Extract track metadata
        track_info = {
            'track_id': track_id,
            'artists': ', '.join([artist['name'] for artist in track['artists']]),
            'album_name': track['album']['name'],
            'release_date': track['album']['release_date'],  # Release date from album info
            'track_name': track['name'],
            'popularity': track['popularity'],
            'duration_ms': track['duration_ms'],
            'explicit': track['explicit'],
            'track_genre': ', '.join(genres)  # Join genres as a comma-separated string
        }

        # Combine track metadata with audio features
        combined_data = {**track_info, **audio_features}
        return combined_data
    else:
        return None

# Collect random tracks and store them in a pandas DataFrame
def collect_random_tracks(access_token, num_tracks=50):
    data = []
    
    while len(data) < num_tracks:
        query = get_random_query()
        random_tracks = search_random_tracks(access_token, query, limit=10)
        
        if random_tracks:
            for track in random_tracks:
                combined_data = get_combined_data(track, access_token)
                if combined_data:
                    data.append(combined_data)
                    if len(data) >= num_tracks:
                        break
    
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data)
    return df

# Example: Collect 50 random tracks with metadata, genres, release date, and audio features
random_tracks_df = collect_random_tracks(access_token, num_tracks=50)

# Display the DataFrame
display(random_tracks_df)
# Out:
# Error fetching audio features: 404 - {
#   "error" : {
#     "status" : 404,
#     "message" : "analysis not found"
#   }
# }
# Error fetching audio features: 404 - {
#   "error" : {
#     "status" : 404,
#     "message" : "analysis not found"
#   }
# }
#                   track_id                      artists  \
# 0   6MzofobZt2dm0Kf1hTThFz                  Addison Rae
# 1   2plbrEY59IikOBgBGLjaoe        Lady Gaga, Bruno Mars
# 2   62bOmKYxYg7dhrC6gH9vFn                       *NSYNC
# 3   2grjqo0Frpf2okIBiifQKs           Earth, Wind & Fire
# 4   2Lumsra3kuU61wXkEKzKaK                   Surf Curse
# 5   5BmB3OaQyYXCqRyN8iR2Yi                   NLE Choppa
# 6   3EaJDYHA0KnX88JvDhL9oa                   Steve Lacy
# 7   5jFA0f4ZDGLbQP4nxzL8D4                      Lomiiel
# 8   0ofHAoxe9vBkTCp2UQIavz                Fleetwood Mac
# 9   0UUpyDCYzkziXJ1TM4awHM                Milli Vanilli
# 10  5AJ9hqTS2wcFQCELCFRO7A                Tommy Richman
# 11  7221xIgOnuakPdLqT0F3nP   Post Malone, Morgan Wallen
# 12  3vkCueOmm7xQDoJ17W1Pm3                       Mitski
# 13  77DRzu7ERs0TX3roZcre7Q               Kendrick Lamar
# 14  003vvx7Niy0yvhvHt4a68B                  The Killers
# 15  0hkoQgoqic1qQtxPOudmrx            emmanuellcortess_
# 16  32fSZSbxeVoiZShMQKLc6Z                Chappell Roan
# 17  3S2R0EVwBSAVMd5UMgKTL0              Michael Jackson
# 18  4QTlxavdQGUVitxAvQqqkU                  BigXthaPlug
# 19  1k2pQc5i348DCHwbn5KTdc                Chappell Roan
# 20  4xdBrk0nFZaP54vvZj0yx7                Chappell Roan
# 21  4ZJ4vzLQekI0WntDbanNC7                   Zach Bryan
# 22  3lUYO6zvXI88sNDpyKvIJ2   NLE Choppa, 41, Kyle Richh
# 23  5N3hjp1WNayUPZrA8kJmJP            Sabrina Carpenter
# 24  3xKsf9qdS1CyvXSMEid6g8                  Frank Ocean
# 25  2qSkIjg1o9h3YT9RAgYN75            Sabrina Carpenter
# 26  2tHwzyyOLoWSFqYNjeVMzj            Sabrina Carpenter
# 27  43SoxERu5UlXAgt4Es1VQU                   Josh Meloy
# 28  6KOEK6SeCEZOQkLj5M1PxH       Katy Perry, Snoop Dogg
# 29  4xdBrk0nFZaP54vvZj0yx7                Chappell Roan
# 30  1k2pQc5i348DCHwbn5KTdc                Chappell Roan
# 31  7fveJ3pk1eSfxBdVkzdXZ0        Morgan Wallen, ERNEST
# 32  3WSOUb3U7tqURbBSgZTrZX                Chappell Roan
# 33  3WOhcATHxK2SLNeP5W3v1v    Charli xcx, Billie Eilish
# 34  5oIVNm56t6OIf9ZjdEG3ud            Sabrina Carpenter
# 35  0WbMK4wrZ1wFSty9F7FCgu                Chappell Roan
# 36  1BxfuPKGuaTgP7aM0Bbdwr                 Taylor Swift
# 37  3fqwjXwUGN6vbzIwvyFMhx              Chris Stapleton
# 38  42VsgItocQwOQC3XWZ8JNA  Travis Scott, Playboi Carti
# 39  3KEMjT3QVfKIl4E9DIcrmF  Travis Scott, Playboi Carti
# 40  53IRnAWx13PYmoVYtemUBS                Chappell Roan
# 41  2Zo1PcszsT9WQ0ANntJbID            Sabrina Carpenter
# 42  4S1VYqwfkLit9mKVY3MXoo                   Alphaville
# 43  1Lo0QY9cvc8sUB2vnIOxDT                   Luke Combs
# 44  5EWPGh7jbTNO2wakv8LjUI               Lynyrd Skynyrd
# 45  2OzhQlSqBEmt7hmkYxfT6m    Taylor Swift, Post Malone
# 46  2hKYtHbwYOSjvYQhVdUpdQ                     GloRilla
# 47  7EkWXAI1wn8Ii883ecd9xr                   Surf Curse
# 48  5G2f63n7IPVPPjfNIGih7Q            Sabrina Carpenter
# 49  0mflMxspEfB0VbI1kyLiAv                   Noah Kahan
#
#                                  album_name release_date  \
# 0                                Diet Pepsi   2024-08-09
# 1                          Die With A Smile   2024-08-16
# 2                       No Strings Attached   2000-03-21
# 3     The Best Of Earth, Wind & Fire Vol. 1   1978-11-23
# 4                                     Disco   2019-06-12
# 5                               SLUT ME OUT   2022-04-22
# 6                                  Dark Red   2017-02-20
# 7                                HAY LUPITA   2024-03-28
# 8                    Rumours (Super Deluxe)   1977-02-04
# 9                     4 Hits: Milli Vanilli   2011-06-03
# 10                      MILLION DOLLAR BABY   2024-04-26
# 11                          I Had Some Help   2024-05-10
# 12   The Land Is Inhospitable and So Are We   2023-09-15
# 13                                 euphoria   2024-04-30
# 14                                 Hot Fuss         2004
# 15                              Memorias <3   2023-07-28
# 16  The Rise and Fall of a Midwest Princess   2023-09-22
# 17         Thriller 25 Super Deluxe Edition   2008-02-08
# 18                              THE BIGGEST   2023-12-01
# 19  The Rise and Fall of a Midwest Princess   2023-09-22
# 20  The Rise and Fall of a Midwest Princess   2023-09-22
# 21                               Pink Skies   2024-05-24
# 22                                  Or What   2024-09-06
# 23                     Please Please Please   2024-06-06
# 24                                   Blonde   2016-08-20
# 25                                 Espresso   2024-04-12
# 26                           Short n' Sweet   2024-08-23
# 27                              Porch Light   2022-11-18
# 28                            Teenage Dream   2010-01-01
# 29  The Rise and Fall of a Midwest Princess   2023-09-22
# 30  The Rise and Fall of a Midwest Princess   2023-09-22
# 31                      One Thing At A Time   2023-03-03
# 32  The Rise and Fall of a Midwest Princess   2023-09-22
# 33            Guess featuring Billie Eilish   2024-08-01
# 34                           Short n' Sweet   2024-08-23
# 35                         Good Luck, Babe!   2024-04-05
# 36                                    Lover   2019-08-23
# 37                                Traveller   2015-05-04
# 38                                   UTOPIA   2023-07-28
# 39                                   UTOPIA   2023-07-26
# 40  The Rise and Fall of a Midwest Princess   2023-09-22
# 41                 emails i can’t send fwd:   2023-03-17
# 42                            Forever Young         1984
# 43                              Gettin' Old   2023-03-24
# 44        Pronounced' Leh-'Nerd 'Skin-'Nerd   1973-01-01
# 45            THE TORTURED POETS DEPARTMENT   2024-04-18
# 46                                     TGIF   2024-06-21
# 47                                   Freaks   2021-05-15
# 48                           Short n' Sweet   2024-08-23
# 49                             Stick Season   2022-10-14
#
#                                            track_name  popularity  \
# 0                                          Diet Pepsi          88
# 1                                    Die With A Smile         100
# 2   Bye Bye Bye - From Deadpool and Wolverine Soun...          87
# 3                                           September          74
# 4                                               Disco          85
# 5                                         SLUT ME OUT          69
# 6                                            Dark Red          85
# 7                                          HAY LUPITA          81
# 8                              Dreams - 2004 Remaster          85
# 9                                Blame It on the Rain          73
# 10                                MILLION DOLLAR BABY          90
# 11              I Had Some Help (Feat. Morgan Wallen)          86
# 12                              My Love Mine All Mine          88
# 13                                           euphoria          80
# 14                                     Mr. Brightside          86
# 15                                               Amor          81
# 16                                   My Kink Is Karma          82
# 17                                           Thriller          72
# 18                                              Mmhmm          80
# 19                                     Pink Pony Club          87
# 20                                         HOT TO GO!          90
# 21                                         Pink Skies          86
# 22                                            Or What          77
# 23                               Please Please Please          92
# 24                                       Pink + White          87
# 25                                           Espresso          93
# 26                               Please Please Please          87
# 27                                        Porch Light          79
# 28                                   California Gurls          72
# 29                                         HOT TO GO!          90
# 30                                     Pink Pony Club          87
# 31                            Cowgirls (feat. ERNEST)          84
# 32                                             Casual          85
# 33                      Guess featuring billie eilish          90
# 34                                        Coincidence          85
# 35                                   Good Luck, Babe!          95
# 36                                       Cruel Summer          90
# 37                                  Tennessee Whiskey          82
# 38                         FE!N (feat. Playboi Carti)          89
# 39                         FE!N (feat. Playboi Carti)          70
# 40                                      Femininomenon          83
# 41                                            Feather          86
# 42                                      Forever Young          85
# 43                                           Fast Car          82
# 44                                          Free Bird          75
# 45                      Fortnight (feat. Post Malone)          86
# 46                                               TGIF          78
# 47                                             Freaks          84
# 48                                              Taste          95
# 49                                       Stick Season          88
#
#     duration_ms  explicit                                        track_genre  \
# 0        169698     False                                   social media pop
# 1        251668     False                            art pop, dance pop, pop
# 2        200400     False                           boy band, dance pop, pop
# 3        215093     False               disco, funk, jazz funk, motown, soul
# 4        152761     False  dreamo, indie surf, pov: indie, surf punk, veg...
# 5        123673      True                               memphis hip hop, rap
# 6        173104     False                                       afrofuturism
# 7        105836     False                                  dembow dominicano
# 8        257800     False  album rock, classic rock, rock, soft rock, yac...
# 9        248533     False            freestyle, new jack swing, new wave pop
# 10       155152     False                             chill abstract hip hop
# 11       178206      True                     dfw rap, melodic rap, pop, rap
# 12       137773     False                         brooklyn indie, pov: indie
# 13       383639      True    conscious hip hop, hip hop, rap, west coast rap
# 14       222973     False  alternative rock, dance rock, modern rock, per...
# 15       202059     False
# 16       222578     False                                          indie pop
# 17       357267     False                                          r&b, soul
# 18       119016      True                                   southern hip hop
# 19       258035     False                                          indie pop
# 20       184841     False                                          indie pop
# 21       194920     False                           classic oklahoma country
# 22       199165      True                               memphis hip hop, rap
# 23       186365      True                                                pop
# 24       184516     False                           lgbtq+ hip hop, neo soul
# 25       175459      True                                                pop
# 26       186365      True                                                pop
# 27       184949      True  classic oklahoma country, modern country pop, ...
# 28       234653     False                                                pop
# 29       184841     False                                          indie pop
# 30       258035     False                                          indie pop
# 31       181621     False                               contemporary country
# 32       232796      True                                          indie pop
# 33       145219     False      art pop, candy pop, metropopolis, pop, uk pop
# 34       164203     False                                                pop
# 35       218424     False                                          indie pop
# 36       178427     False                                                pop
# 37       293293     False               contemporary country, outlaw country
# 38       191701      True                                    rap, slap house
# 39       191702     False                                    rap, slap house
# 40       219711      True                                          indie pop
# 41       185553      True                                                pop
# 42       226706     False               new romantic, new wave pop, synthpop
# 43       265493     False                      contemporary country, country
# 44       547107     False  album rock, classic rock, hard rock, rock, sou...
# 45       228965     False                                                pop
# 46       164571      True                                   southern hip hop
# 47       147062     False  dreamo, indie surf, pov: indie, surf punk, veg...
# 48       157280     False                                                pop
# 49       182347     False                  pov: indie, singer-songwriter pop
#
#     danceability  ...  instrumentalness  liveness  valence    tempo  \
# 0          0.669  ...          0.009620    0.0954    0.841  150.069
# 1          0.521  ...          0.000000    0.1220    0.535  157.969
# 2          0.610  ...          0.001200    0.0821    0.861  172.638
# 3          0.697  ...          0.001310    0.2690    0.979  125.926
# 4          0.473  ...          0.000366    0.1900    0.782  173.083
# 5          0.938  ...          0.000000    0.5280    0.706  121.108
# 6          0.603  ...          0.000008    0.1190    0.769  172.041
# 7          0.845  ...          0.000459    0.1100    0.903  145.078
# 8          0.828  ...          0.004280    0.1280    0.789  120.151
# 9          0.758  ...          0.000169    0.0946    0.506   97.515
# 10         0.852  ...          0.000370    0.0678    0.919  138.029
# 11         0.638  ...          0.000000    0.2450    0.731  127.986
# 12         0.504  ...          0.135000    0.1580    0.121  113.950
# 13         0.831  ...          0.000000    0.0840    0.142  139.948
# 14         0.352  ...          0.000000    0.0995    0.236  148.033
# 15         0.717  ...          0.000013    0.1200    0.424  180.010
# 16         0.555  ...          0.000000    0.1020    0.415   86.727
# 17         0.773  ...          0.000187    0.9140    0.813  118.459
# 18         0.930  ...          0.000000    0.1290    0.962  126.003
# 19         0.610  ...          0.000000    0.1100    0.507  106.719
# 20         0.742  ...          0.000000    0.3050    0.957  139.982
# 21         0.525  ...          0.000051    0.1350    0.253   84.999
# 22         0.731  ...          0.000000    0.0987    0.147  125.845
# 23         0.669  ...          0.000000    0.1040    0.579  107.071
# 24         0.545  ...          0.000055    0.4170    0.549  159.940
# 25         0.701  ...          0.000065    0.1850    0.690  103.969
# 26         0.675  ...          0.000000    0.1040    0.621  107.015
# 27         0.647  ...          0.000000    0.1590    0.477  142.034
# 28         0.789  ...          0.000000    0.1800    0.403  125.007
# 29         0.742  ...          0.000000    0.3050    0.957  139.982
# 30         0.610  ...          0.000000    0.1100    0.507  106.719
# 31         0.621  ...          0.000009    0.1650    0.399  172.037
# 32         0.508  ...          0.000000    0.0571    0.340  131.008
# 33         0.776  ...          0.300000    0.0761    0.618  130.019
# 34         0.418  ...          0.000000    0.1250    0.758   77.862
# 35         0.700  ...          0.000000    0.0881    0.785  116.712
# 36         0.552  ...          0.000021    0.1050    0.564  169.994
# 37         0.392  ...          0.009600    0.0821    0.512   48.718
# 38         0.569  ...          0.000000    0.1420    0.201  148.038
# 39         0.576  ...          0.000000    0.1400    0.156  147.969
# 40         0.609  ...          0.000005    0.1100    0.236  124.949
# 41         0.791  ...          0.000002    0.0958    0.826  123.508
# 42         0.489  ...          0.002270    0.2350    0.330  136.803
# 43         0.712  ...          0.000000    0.1150    0.670   97.994
# 44         0.249  ...          0.000097    0.0924    0.337  118.222
# 45         0.504  ...          0.000015    0.0961    0.281  192.004
# 46         0.891  ...          0.000030    0.1330    0.203  140.060
# 47         0.345  ...          0.633000    0.0511    0.407  179.626
# 48         0.674  ...          0.000000    0.2970    0.721  112.964
# 49         0.664  ...          0.000000    0.0966    0.801  117.896
#
#               type                      id  \
# 0   audio_features  6MzofobZt2dm0Kf1hTThFz
# 1   audio_features  2plbrEY59IikOBgBGLjaoe
# 2   audio_features  62bOmKYxYg7dhrC6gH9vFn
# 3   audio_features  2grjqo0Frpf2okIBiifQKs
# 4   audio_features  2Lumsra3kuU61wXkEKzKaK
# 5   audio_features  5BmB3OaQyYXCqRyN8iR2Yi
# 6   audio_features  3EaJDYHA0KnX88JvDhL9oa
# 7   audio_features  5jFA0f4ZDGLbQP4nxzL8D4
# 8   audio_features  0ofHAoxe9vBkTCp2UQIavz
# 9   audio_features  0UUpyDCYzkziXJ1TM4awHM
# 10  audio_features  5AJ9hqTS2wcFQCELCFRO7A
# 11  audio_features  7221xIgOnuakPdLqT0F3nP
# 12  audio_features  3vkCueOmm7xQDoJ17W1Pm3
# 13  audio_features  77DRzu7ERs0TX3roZcre7Q
# 14  audio_features  003vvx7Niy0yvhvHt4a68B
# 15  audio_features  0hkoQgoqic1qQtxPOudmrx
# 16  audio_features  32fSZSbxeVoiZShMQKLc6Z
# 17  audio_features  3S2R0EVwBSAVMd5UMgKTL0
# 18  audio_features  4QTlxavdQGUVitxAvQqqkU
# 19  audio_features  1k2pQc5i348DCHwbn5KTdc
# 20  audio_features  4xdBrk0nFZaP54vvZj0yx7
# 21  audio_features  4ZJ4vzLQekI0WntDbanNC7
# 22  audio_features  3lUYO6zvXI88sNDpyKvIJ2
# 23  audio_features  5N3hjp1WNayUPZrA8kJmJP
# 24  audio_features  3xKsf9qdS1CyvXSMEid6g8
# 25  audio_features  2qSkIjg1o9h3YT9RAgYN75
# 26  audio_features  2tHwzyyOLoWSFqYNjeVMzj
# 27  audio_features  43SoxERu5UlXAgt4Es1VQU
# 28  audio_features  6KOEK6SeCEZOQkLj5M1PxH
# 29  audio_features  4xdBrk0nFZaP54vvZj0yx7
# 30  audio_features  1k2pQc5i348DCHwbn5KTdc
# 31  audio_features  7fveJ3pk1eSfxBdVkzdXZ0
# 32  audio_features  3WSOUb3U7tqURbBSgZTrZX
# 33  audio_features  3WOhcATHxK2SLNeP5W3v1v
# 34  audio_features  5oIVNm56t6OIf9ZjdEG3ud
# 35  audio_features  0WbMK4wrZ1wFSty9F7FCgu
# 36  audio_features  1BxfuPKGuaTgP7aM0Bbdwr
# 37  audio_features  3fqwjXwUGN6vbzIwvyFMhx
# 38  audio_features  42VsgItocQwOQC3XWZ8JNA
# 39  audio_features  3KEMjT3QVfKIl4E9DIcrmF
# 40  audio_features  53IRnAWx13PYmoVYtemUBS
# 41  audio_features  2Zo1PcszsT9WQ0ANntJbID
# 42  audio_features  4S1VYqwfkLit9mKVY3MXoo
# 43  audio_features  1Lo0QY9cvc8sUB2vnIOxDT
# 44  audio_features  5EWPGh7jbTNO2wakv8LjUI
# 45  audio_features  2OzhQlSqBEmt7hmkYxfT6m
# 46  audio_features  2hKYtHbwYOSjvYQhVdUpdQ
# 47  audio_features  7EkWXAI1wn8Ii883ecd9xr
# 48  audio_features  5G2f63n7IPVPPjfNIGih7Q
# 49  audio_features  0mflMxspEfB0VbI1kyLiAv
#
#                                      uri  \
# 0   spotify:track:6MzofobZt2dm0Kf1hTThFz
# 1   spotify:track:2plbrEY59IikOBgBGLjaoe
# 2   spotify:track:62bOmKYxYg7dhrC6gH9vFn
# 3   spotify:track:2grjqo0Frpf2okIBiifQKs
# 4   spotify:track:2Lumsra3kuU61wXkEKzKaK
# 5   spotify:track:5BmB3OaQyYXCqRyN8iR2Yi
# 6   spotify:track:3EaJDYHA0KnX88JvDhL9oa
# 7   spotify:track:5jFA0f4ZDGLbQP4nxzL8D4
# 8   spotify:track:0ofHAoxe9vBkTCp2UQIavz
# 9   spotify:track:0UUpyDCYzkziXJ1TM4awHM
# 10  spotify:track:5AJ9hqTS2wcFQCELCFRO7A
# 11  spotify:track:7221xIgOnuakPdLqT0F3nP
# 12  spotify:track:3vkCueOmm7xQDoJ17W1Pm3
# 13  spotify:track:77DRzu7ERs0TX3roZcre7Q
# 14  spotify:track:003vvx7Niy0yvhvHt4a68B
# 15  spotify:track:0hkoQgoqic1qQtxPOudmrx
# 16  spotify:track:32fSZSbxeVoiZShMQKLc6Z
# 17  spotify:track:3S2R0EVwBSAVMd5UMgKTL0
# 18  spotify:track:4QTlxavdQGUVitxAvQqqkU
# 19  spotify:track:1k2pQc5i348DCHwbn5KTdc
# 20  spotify:track:4xdBrk0nFZaP54vvZj0yx7
# 21  spotify:track:4ZJ4vzLQekI0WntDbanNC7
# 22  spotify:track:3lUYO6zvXI88sNDpyKvIJ2
# 23  spotify:track:5N3hjp1WNayUPZrA8kJmJP
# 24  spotify:track:3xKsf9qdS1CyvXSMEid6g8
# 25  spotify:track:2qSkIjg1o9h3YT9RAgYN75
# 26  spotify:track:2tHwzyyOLoWSFqYNjeVMzj
# 27  spotify:track:43SoxERu5UlXAgt4Es1VQU
# 28  spotify:track:6KOEK6SeCEZOQkLj5M1PxH
# 29  spotify:track:4xdBrk0nFZaP54vvZj0yx7
# 30  spotify:track:1k2pQc5i348DCHwbn5KTdc
# 31  spotify:track:7fveJ3pk1eSfxBdVkzdXZ0
# 32  spotify:track:3WSOUb3U7tqURbBSgZTrZX
# 33  spotify:track:3WOhcATHxK2SLNeP5W3v1v
# 34  spotify:track:5oIVNm56t6OIf9ZjdEG3ud
# 35  spotify:track:0WbMK4wrZ1wFSty9F7FCgu
# 36  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 37  spotify:track:3fqwjXwUGN6vbzIwvyFMhx
# 38  spotify:track:42VsgItocQwOQC3XWZ8JNA
# 39  spotify:track:3KEMjT3QVfKIl4E9DIcrmF
# 40  spotify:track:53IRnAWx13PYmoVYtemUBS
# 41  spotify:track:2Zo1PcszsT9WQ0ANntJbID
# 42  spotify:track:4S1VYqwfkLit9mKVY3MXoo
# 43  spotify:track:1Lo0QY9cvc8sUB2vnIOxDT
# 44  spotify:track:5EWPGh7jbTNO2wakv8LjUI
# 45  spotify:track:2OzhQlSqBEmt7hmkYxfT6m
# 46  spotify:track:2hKYtHbwYOSjvYQhVdUpdQ
# 47  spotify:track:7EkWXAI1wn8Ii883ecd9xr
# 48  spotify:track:5G2f63n7IPVPPjfNIGih7Q
# 49  spotify:track:0mflMxspEfB0VbI1kyLiAv
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6MzofobZt2dm...
# 1   https://api.spotify.com/v1/tracks/2plbrEY59Iik...
# 2   https://api.spotify.com/v1/tracks/62bOmKYxYg7d...
# 3   https://api.spotify.com/v1/tracks/2grjqo0Frpf2...
# 4   https://api.spotify.com/v1/tracks/2Lumsra3kuU6...
# 5   https://api.spotify.com/v1/tracks/5BmB3OaQyYXC...
# 6   https://api.spotify.com/v1/tracks/3EaJDYHA0KnX...
# 7   https://api.spotify.com/v1/tracks/5jFA0f4ZDGLb...
# 8   https://api.spotify.com/v1/tracks/0ofHAoxe9vBk...
# 9   https://api.spotify.com/v1/tracks/0UUpyDCYzkzi...
# 10  https://api.spotify.com/v1/tracks/5AJ9hqTS2wcF...
# 11  https://api.spotify.com/v1/tracks/7221xIgOnuak...
# 12  https://api.spotify.com/v1/tracks/3vkCueOmm7xQ...
# 13  https://api.spotify.com/v1/tracks/77DRzu7ERs0T...
# 14  https://api.spotify.com/v1/tracks/003vvx7Niy0y...
# 15  https://api.spotify.com/v1/tracks/0hkoQgoqic1q...
# 16  https://api.spotify.com/v1/tracks/32fSZSbxeVoi...
# 17  https://api.spotify.com/v1/tracks/3S2R0EVwBSAV...
# 18  https://api.spotify.com/v1/tracks/4QTlxavdQGUV...
# 19  https://api.spotify.com/v1/tracks/1k2pQc5i348D...
# 20  https://api.spotify.com/v1/tracks/4xdBrk0nFZaP...
# 21  https://api.spotify.com/v1/tracks/4ZJ4vzLQekI0...
# 22  https://api.spotify.com/v1/tracks/3lUYO6zvXI88...
# 23  https://api.spotify.com/v1/tracks/5N3hjp1WNayU...
# 24  https://api.spotify.com/v1/tracks/3xKsf9qdS1Cy...
# 25  https://api.spotify.com/v1/tracks/2qSkIjg1o9h3...
# 26  https://api.spotify.com/v1/tracks/2tHwzyyOLoWS...
# 27  https://api.spotify.com/v1/tracks/43SoxERu5UlX...
# 28  https://api.spotify.com/v1/tracks/6KOEK6SeCEZO...
# 29  https://api.spotify.com/v1/tracks/4xdBrk0nFZaP...
# 30  https://api.spotify.com/v1/tracks/1k2pQc5i348D...
# 31  https://api.spotify.com/v1/tracks/7fveJ3pk1eSf...
# 32  https://api.spotify.com/v1/tracks/3WSOUb3U7tqU...
# 33  https://api.spotify.com/v1/tracks/3WOhcATHxK2S...
# 34  https://api.spotify.com/v1/tracks/5oIVNm56t6OI...
# 35  https://api.spotify.com/v1/tracks/0WbMK4wrZ1wF...
# 36  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 37  https://api.spotify.com/v1/tracks/3fqwjXwUGN6v...
# 38  https://api.spotify.com/v1/tracks/42VsgItocQwO...
# 39  https://api.spotify.com/v1/tracks/3KEMjT3QVfKI...
# 40  https://api.spotify.com/v1/tracks/53IRnAWx13PY...
# 41  https://api.spotify.com/v1/tracks/2Zo1PcszsT9W...
# 42  https://api.spotify.com/v1/tracks/4S1VYqwfkLit...
# 43  https://api.spotify.com/v1/tracks/1Lo0QY9cvc8s...
# 44  https://api.spotify.com/v1/tracks/5EWPGh7jbTNO...
# 45  https://api.spotify.com/v1/tracks/2OzhQlSqBEmt...
# 46  https://api.spotify.com/v1/tracks/2hKYtHbwYOSj...
# 47  https://api.spotify.com/v1/tracks/7EkWXAI1wn8I...
# 48  https://api.spotify.com/v1/tracks/5G2f63n7IPVP...
# 49  https://api.spotify.com/v1/tracks/0mflMxspEfB0...
#
#                                          analysis_url  time_signature
# 0   https://api.spotify.com/v1/audio-analysis/6Mzo...               4
# 1   https://api.spotify.com/v1/audio-analysis/2plb...               3
# 2   https://api.spotify.com/v1/audio-analysis/62bO...               4
# 3   https://api.spotify.com/v1/audio-analysis/2grj...               4
# 4   https://api.spotify.com/v1/audio-analysis/2Lum...               4
# 5   https://api.spotify.com/v1/audio-analysis/5BmB...               4
# 6   https://api.spotify.com/v1/audio-analysis/3EaJ...               4
# 7   https://api.spotify.com/v1/audio-analysis/5jFA...               4
# 8   https://api.spotify.com/v1/audio-analysis/0ofH...               4
# 9   https://api.spotify.com/v1/audio-analysis/0UUp...               4
# 10  https://api.spotify.com/v1/audio-analysis/5AJ9...               4
# 11  https://api.spotify.com/v1/audio-analysis/7221...               4
# 12  https://api.spotify.com/v1/audio-analysis/3vkC...               4
# 13  https://api.spotify.com/v1/audio-analysis/77DR...               4
# 14  https://api.spotify.com/v1/audio-analysis/003v...               4
# 15  https://api.spotify.com/v1/audio-analysis/0hko...               4
# 16  https://api.spotify.com/v1/audio-analysis/32fS...               4
# 17  https://api.spotify.com/v1/audio-analysis/3S2R...               4
# 18  https://api.spotify.com/v1/audio-analysis/4QTl...               4
# 19  https://api.spotify.com/v1/audio-analysis/1k2p...               4
# 20  https://api.spotify.com/v1/audio-analysis/4xdB...               4
# 21  https://api.spotify.com/v1/audio-analysis/4ZJ4...               4
# 22  https://api.spotify.com/v1/audio-analysis/3lUY...               4
# 23  https://api.spotify.com/v1/audio-analysis/5N3h...               4
# 24  https://api.spotify.com/v1/audio-analysis/3xKs...               3
# 25  https://api.spotify.com/v1/audio-analysis/2qSk...               4
# 26  https://api.spotify.com/v1/audio-analysis/2tHw...               4
# 27  https://api.spotify.com/v1/audio-analysis/43So...               4
# 28  https://api.spotify.com/v1/audio-analysis/6KOE...               4
# 29  https://api.spotify.com/v1/audio-analysis/4xdB...               4
# 30  https://api.spotify.com/v1/audio-analysis/1k2p...               4
# 31  https://api.spotify.com/v1/audio-analysis/7fve...               4
# 32  https://api.spotify.com/v1/audio-analysis/3WSO...               4
# 33  https://api.spotify.com/v1/audio-analysis/3WOh...               4
# 34  https://api.spotify.com/v1/audio-analysis/5oIV...               4
# 35  https://api.spotify.com/v1/audio-analysis/0WbM...               4
# 36  https://api.spotify.com/v1/audio-analysis/1Bxf...               4
# 37  https://api.spotify.com/v1/audio-analysis/3fqw...               4
# 38  https://api.spotify.com/v1/audio-analysis/42Vs...               4
# 39  https://api.spotify.com/v1/audio-analysis/3KEM...               4
# 40  https://api.spotify.com/v1/audio-analysis/53IR...               4
# 41  https://api.spotify.com/v1/audio-analysis/2Zo1...               4
# 42  https://api.spotify.com/v1/audio-analysis/4S1V...               4
# 43  https://api.spotify.com/v1/audio-analysis/1Lo0...               4
# 44  https://api.spotify.com/v1/audio-analysis/5EWP...               4
# 45  https://api.spotify.com/v1/audio-analysis/2Ozh...               4
# 46  https://api.spotify.com/v1/audio-analysis/2hKY...               4
# 47  https://api.spotify.com/v1/audio-analysis/7EkW...               4
# 48  https://api.spotify.com/v1/audio-analysis/5G2f...               4
# 49  https://api.spotify.com/v1/audio-analysis/0mfl...               4
#
# [50 rows x 26 columns]
