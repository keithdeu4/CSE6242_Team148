# %%
import requests
import random
import string
import base64
import os
import csv
import time

# Spotify API credentials
client_id = '13c533aa9722416793be9e5df13fa0ec'
client_secret = '0bcd029bae3f4ad19efa068b2c3ea733'

# File path to store artist data
file_path = "spotify_artists.csv"

# Step 1: Obtain an Access Token
def get_access_token(client_id, client_secret):
    token_url = 'https://accounts.spotify.com/api/token'
    client_creds = f"{client_id}:{client_secret}"
    client_creds_b64 = base64.b64encode(client_creds.encode()).decode()
    
    headers = {'Authorization': f'Basic {client_creds_b64}'}
    data = {'grant_type': 'client_credentials'}
    
    response = requests.post(token_url, headers=headers, data=data)
    if response.status_code == 200:
        print("Successfully obtained access token.")
        return response.json()['access_token']
    else:
        raise Exception(f"Failed to get access token: {response.status_code} - {response.text}")

# Step 2: Search Spotify for random artist IDs
def get_random_artist_ids(access_token, limit=50):
    url = "https://api.spotify.com/v1/search"
    headers = {'Authorization': f'Bearer {access_token}'}
    params = {
        'q': ''.join(random.choice(string.ascii_lowercase) for _ in range(3)),
        'type': 'artist',
        'limit': limit
    }
    
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        artist_items = response.json()['artists']['items']
        artist_ids = [artist['id'] for artist in artist_items]
        print(f"Retrieved {len(artist_ids)} artist IDs.")
        return artist_ids
    elif response.status_code == 429:  # Rate limit
        retry_after = int(response.headers.get("Retry-After", 5))
        print(f"Rate limit hit. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        return get_random_artist_ids(access_token, limit)
    else:
        print(f"Failed to search for artist IDs: {response.status_code} - {response.text}")
        return []

# Step 3: Get Artist Details for a List of IDs
def get_artists_details(access_token, artist_ids):
    url = "https://api.spotify.com/v1/artists"
    headers = {'Authorization': f'Bearer {access_token}'}
    params = {'ids': ','.join(artist_ids)}
    
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json().get('artists', [])
    elif response.status_code == 429:  # Rate limit
        retry_after = int(response.headers.get("Retry-After", 5))
        print(f"Rate limit hit. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        return get_artists_details(access_token, artist_ids)
    else:
        print(f"Failed to retrieve artist details: {response.status_code} - {response.text}")
        return []

# Step 4: Write artist details to CSV
def write_artists_to_csv(artists):
    file_exists = os.path.isfile(file_path)
    with open(file_path, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        if not file_exists:
            writer.writerow(['id', 'name', 'popularity', 'followers', 'genres', 'url'])  # CSV headers
        for artist in artists:
            genres = ", ".join(artist.get('genres', []))
            writer.writerow([
                artist['id'],
                artist['name'],
                artist['popularity'],
                artist['followers']['total'],
                genres,
                artist['external_urls']['spotify']
            ])
    print(f"Wrote {len(artists)} artists to CSV.")

# Step 5: Main Function to Collect 100,000 Artist Names
def collect_artists(access_token, target_count=100000):
    artist_ids = set()  # Use a set to avoid duplicate IDs
    total_collected = 0
    
    while total_collected < target_count:
        # Step 5.1: Gather unique artist IDs until we have enough for a batch request
        while len(artist_ids) < 50:
            new_ids = get_random_artist_ids(access_token, limit=50 - len(artist_ids))
            artist_ids.update(new_ids)
        
        # Step 5.2: Get artist details in batches of up to 50
        batch_ids = list(artist_ids)[:50]
        artist_details = get_artists_details(access_token, batch_ids)
        write_artists_to_csv(artist_details)
        
        # Update count and clear processed IDs
        total_collected += len(artist_details)
        artist_ids.difference_update(batch_ids)  # Remove processed IDs
        
        print(f"Total artists collected so far: {total_collected}")
        if total_collected >= target_count:
            break

# Run the collection process
if __name__ == "__main__":
    access_token = get_access_token(client_id, client_secret)
    collect_artists(access_token, target_count=100000)
# Out:
# Successfully obtained access token.
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 50
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 100
# Retrieved 18 artist IDs.
# Retrieved 32 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 150
# Retrieved 34 artist IDs.
# Retrieved 16 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 200
# Retrieved 25 artist IDs.
# Retrieved 25 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 350
# Retrieved 38 artist IDs.
# Retrieved 12 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 500
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 550
# Retrieved 20 artist IDs.
# Retrieved 30 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 750
# Retrieved 4 artist IDs.
# Retrieved 46 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 950
# Retrieved 39 artist IDs.
# Retrieved 11 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1100
# Retrieved 26 artist IDs.
# Retrieved 16 artist IDs.
# Retrieved 8 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1200
# Retrieved 4 artist IDs.
# Retrieved 32 artist IDs.
# Retrieved 14 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1450
# Retrieved 42 artist IDs.
# Retrieved 8 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1500
# Retrieved 38 artist IDs.
# Retrieved 3 artist IDs.
# Retrieved 9 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1700
# Retrieved 0 artist IDs.
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1850
# Retrieved 8 artist IDs.
# Retrieved 4 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1900
# Retrieved 30 artist IDs.
# Retrieved 20 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 1950
# Retrieved 10 artist IDs.
# Retrieved 40 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2000
# Retrieved 31 artist IDs.
# Retrieved 19 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2050
# Retrieved 33 artist IDs.
# Retrieved 17 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2150
# Retrieved 46 artist IDs.
# Retrieved 1 artist IDs.
# Retrieved 2 artist IDs.
# Retrieved 1 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2200
# Retrieved 48 artist IDs.
# Retrieved 2 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2450
# Retrieved 14 artist IDs.
# Retrieved 36 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2550
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2700
# Retrieved 18 artist IDs.
# Retrieved 3 artist IDs.
# Retrieved 29 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2750
# Retrieved 12 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2850
# Retrieved 10 artist IDs.
# Retrieved 40 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 2950
# Retrieved 4 artist IDs.
# Retrieved 23 artist IDs.
# Retrieved 18 artist IDs.
# Retrieved 5 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3000
# Retrieved 10 artist IDs.
# Retrieved 40 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3150
# Retrieved 4 artist IDs.
# Retrieved 32 artist IDs.
# Retrieved 6 artist IDs.
# Retrieved 8 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3200
# Retrieved 47 artist IDs.
# Retrieved 3 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3550
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3600
# Retrieved 23 artist IDs.
# Retrieved 27 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3700
# Retrieved 15 artist IDs.
# Retrieved 35 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3750
# Retrieved 15 artist IDs.
# Retrieved 35 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3850
# Retrieved 19 artist IDs.
# Retrieved 31 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 3950
# Retrieved 29 artist IDs.
# Retrieved 21 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4100
# Retrieved 7 artist IDs.
# Retrieved 43 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4150
# Retrieved 16 artist IDs.
# Retrieved 31 artist IDs.
# Retrieved 3 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4250
# Retrieved 13 artist IDs.
# Retrieved 31 artist IDs.
# Retrieved 6 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4500
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4550
# Retrieved 25 artist IDs.
# Retrieved 25 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4650
# Retrieved 39 artist IDs.
# Retrieved 11 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4700
# Retrieved 22 artist IDs.
# Retrieved 28 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4800
# Retrieved 48 artist IDs.
# Retrieved 2 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 4950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5100
# Retrieved 13 artist IDs.
# Retrieved 37 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5150
# Retrieved 25 artist IDs.
# Retrieved 16 artist IDs.
# Retrieved 9 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5200
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5300
# Retrieved 37 artist IDs.
# Retrieved 13 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5600
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5850
# Retrieved 11 artist IDs.
# Retrieved 20 artist IDs.
# Retrieved 19 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 5950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6350
# Retrieved 34 artist IDs.
# Retrieved 13 artist IDs.
# Retrieved 3 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6450
# Retrieved 6 artist IDs.
# Retrieved 36 artist IDs.
# Retrieved 8 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6550
# Retrieved 11 artist IDs.
# Retrieved 39 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6750
# Retrieved 18 artist IDs.
# Retrieved 32 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6800
# Retrieved 9 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6900
# Retrieved 20 artist IDs.
# Retrieved 10 artist IDs.
# Retrieved 20 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 6950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7100
# Retrieved 19 artist IDs.
# Retrieved 13 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7300
# Retrieved 2 artist IDs.
# Retrieved 48 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7350
# Retrieved 12 artist IDs.
# Retrieved 25 artist IDs.
# Retrieved 13 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7400
# Retrieved 1 artist IDs.
# Retrieved 49 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7500
# Retrieved 4 artist IDs.
# Retrieved 5 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7700
# Retrieved 8 artist IDs.
# Retrieved 42 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7750
# Retrieved 2 artist IDs.
# Retrieved 13 artist IDs.
# Retrieved 35 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7800
# Retrieved 12 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7900
# Retrieved 9 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 7950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8100
# Retrieved 14 artist IDs.
# Retrieved 29 artist IDs.
# Retrieved 7 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8150
# Retrieved 12 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8500
# Retrieved 8 artist IDs.
# Retrieved 42 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8550
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8750
# Retrieved 0 artist IDs.
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8900
# Retrieved 7 artist IDs.
# Retrieved 43 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 8950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9000
# Retrieved 18 artist IDs.
# Retrieved 32 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9050
# Retrieved 2 artist IDs.
# Retrieved 11 artist IDs.
# Retrieved 4 artist IDs.
# Retrieved 33 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9100
# Retrieved 11 artist IDs.
# Retrieved 39 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9250
# Retrieved 8 artist IDs.
# Retrieved 42 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9300
# Retrieved 8 artist IDs.
# Retrieved 42 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9350
# Retrieved 3 artist IDs.
# Retrieved 47 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9400
# Retrieved 11 artist IDs.
# Retrieved 39 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9450
# Retrieved 2 artist IDs.
# Retrieved 48 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9550
# Retrieved 1 artist IDs.
# Retrieved 49 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9600
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9650
# Retrieved 1 artist IDs.
# Retrieved 27 artist IDs.
# Retrieved 22 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9850
# Retrieved 34 artist IDs.
# Retrieved 16 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 9950
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10050
# Retrieved 9 artist IDs.
# Retrieved 6 artist IDs.
# Retrieved 35 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10100
# Retrieved 16 artist IDs.
# Retrieved 34 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10150
# Retrieved 12 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10250
# Retrieved 9 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10350
# Retrieved 33 artist IDs.
# Retrieved 17 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10400
# Retrieved 12 artist IDs.
# Retrieved 9 artist IDs.
# Retrieved 29 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10700
# Retrieved 0 artist IDs.
# Retrieved 47 artist IDs.
# Retrieved 3 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 10950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11000
# Retrieved 43 artist IDs.
# Retrieved 7 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11050
# Retrieved 24 artist IDs.
# Retrieved 26 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11150
# Retrieved 45 artist IDs.
# Retrieved 5 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11450
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 11950
# Retrieved 19 artist IDs.
# Retrieved 1 artist IDs.
# Retrieved 12 artist IDs.
# Retrieved 4 artist IDs.
# Retrieved 14 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12200
# Retrieved 16 artist IDs.
# Retrieved 34 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12300
# Retrieved 26 artist IDs.
# Retrieved 8 artist IDs.
# Retrieved 16 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12650
# Retrieved 9 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12700
# Retrieved 2 artist IDs.
# Retrieved 48 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12750
# Retrieved 21 artist IDs.
# Retrieved 29 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12800
# Retrieved 11 artist IDs.
# Retrieved 39 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12850
# Retrieved 46 artist IDs.
# Retrieved 4 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 12950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13050
# Retrieved 7 artist IDs.
# Retrieved 12 artist IDs.
# Retrieved 31 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13100
# Retrieved 30 artist IDs.
# Retrieved 20 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13200
# Retrieved 36 artist IDs.
# Retrieved 14 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13350
# Retrieved 1 artist IDs.
# Retrieved 49 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13550
# Retrieved 25 artist IDs.
# Retrieved 25 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13600
# Retrieved 5 artist IDs.
# Retrieved 40 artist IDs.
# Retrieved 5 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13700
# Retrieved 30 artist IDs.
# Retrieved 20 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 13950
# Retrieved 2 artist IDs.
# Retrieved 48 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14050
# Retrieved 5 artist IDs.
# Retrieved 7 artist IDs.
# Retrieved 38 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14100
# Retrieved 17 artist IDs.
# Retrieved 33 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14200
# Retrieved 28 artist IDs.
# Retrieved 22 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14250
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14300
# Retrieved 9 artist IDs.
# Retrieved 41 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14350
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14450
# Retrieved 19 artist IDs.
# Retrieved 31 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14550
# Retrieved 1 artist IDs.
# Retrieved 49 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14650
# Retrieved 39 artist IDs.
# Retrieved 11 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14700
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14850
# Retrieved 46 artist IDs.
# Retrieved 4 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14900
# Retrieved 0 artist IDs.
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 14950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15000
# Retrieved 46 artist IDs.
# Retrieved 4 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15200
# Retrieved 23 artist IDs.
# Retrieved 2 artist IDs.
# Retrieved 25 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15250
# Retrieved 1 artist IDs.
# Retrieved 11 artist IDs.
# Retrieved 34 artist IDs.
# Retrieved 4 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15300
# Retrieved 8 artist IDs.
# Retrieved 42 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15350
# Retrieved 20 artist IDs.
# Retrieved 30 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15400
# Retrieved 7 artist IDs.
# Retrieved 43 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15500
# Retrieved 14 artist IDs.
# Retrieved 18 artist IDs.
# Retrieved 11 artist IDs.
# Retrieved 7 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15850
# Retrieved 0 artist IDs.
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15900
# Retrieved 36 artist IDs.
# Retrieved 14 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 15950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16050
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16150
# Retrieved 14 artist IDs.
# Retrieved 36 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16200
# Retrieved 32 artist IDs.
# Retrieved 18 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16250
# Retrieved 23 artist IDs.
# Retrieved 27 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16350
# Retrieved 1 artist IDs.
# Retrieved 49 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16400
# Retrieved 46 artist IDs.
# Retrieved 4 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16450
# Retrieved 40 artist IDs.
# Retrieved 10 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16500
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16550
# Retrieved 21 artist IDs.
# Retrieved 29 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16600
# Retrieved 4 artist IDs.
# Retrieved 10 artist IDs.
# Retrieved 36 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16650
# Retrieved 31 artist IDs.
# Retrieved 19 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16700
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16900
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 16950
# Retrieved 5 artist IDs.
# Retrieved 13 artist IDs.
# Retrieved 32 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17000
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17050
# Retrieved 5 artist IDs.
# Retrieved 45 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17100
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17150
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17200
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17250
# Retrieved 6 artist IDs.
# Retrieved 44 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17300
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17350
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17400
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17450
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17500
# Retrieved 5 artist IDs.
# Retrieved 2 artist IDs.
# Retrieved 8 artist IDs.
# Retrieved 35 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17550
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17600
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17650
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17700
# Retrieved 0 artist IDs.
# Retrieved 14 artist IDs.
# Retrieved 36 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17750
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17800
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17850
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17900
# Retrieved 31 artist IDs.
# Retrieved 19 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 17950
# Retrieved 50 artist IDs.
# Wrote 50 artists to CSV.
# Total artists collected so far: 18000
# Retrieved 3 artist IDs.
# Retrieved 1 artist IDs.
# Retrieved 29 artist IDs.
# Retrieved 17 artist IDs.
# Rate limit hit. Retrying in 72729 seconds.

# %%
import requests
import random
import string
import base64
import os
import csv
import time

# Spotify API credentials
client_id = '13c533aa9722416793be9e5df13fa0ec'
client_secret = '0bcd029bae3f4ad19efa068b2c3ea733'

# File paths
artist_file_path = "spotify_artists.csv"
track_file_path = "spotify_top_tracks.csv"

# Step 1: Obtain an Access Token
def get_access_token(client_id, client_secret):
    token_url = 'https://accounts.spotify.com/api/token'
    client_creds = f"{client_id}:{client_secret}"
    client_creds_b64 = base64.b64encode(client_creds.encode()).decode()
    
    headers = {'Authorization': f'Basic {client_creds_b64}'}
    data = {'grant_type': 'client_credentials'}
    
    response = requests.post(token_url, headers=headers, data=data)
    if response.status_code == 200:
        print("Successfully obtained access token.")
        return response.json()['access_token']
    else:
        raise Exception(f"Failed to get access token: {response.status_code} - {response.text}")

# Step 2: Read artist IDs from the CSV file
def read_artist_ids(file_path):
    artist_ids = []
    with open(file_path, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            artist_ids.append(row['id'])
    print(f"Loaded {len(artist_ids)} artist IDs from file.")
    return artist_ids

# Step 3: Get Top Tracks for a Given Artist ID
def get_top_tracks(access_token, artist_id, country='US', limit=5):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
    headers = {'Authorization': f'Bearer {access_token}'}
    params = {'market': country}  # The country parameter affects popularity ranking
    
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        top_tracks = response.json()['tracks'][:limit]  # Limit to top `n` tracks
        return top_tracks
    elif response.status_code == 429:  # Rate limit
        retry_after = int(response.headers.get("Retry-After", 5))
        print(f"Rate limit hit. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        return get_top_tracks(access_token, artist_id, country, limit)
    else:
        print(f"Failed to retrieve top tracks for artist ID {artist_id}: {response.status_code} - {response.text}")
        return []

# Step 4: Get Audio Features for Multiple Tracks
def get_audio_features_batch(access_token, track_ids):
    url = "https://api.spotify.com/v1/audio-features"
    headers = {'Authorization': f'Bearer {access_token}'}
    params = {'ids': ','.join(track_ids)}
    time.sleep(30)
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()['audio_features']
    elif response.status_code == 429:  # Rate limit
        retry_after = int(response.headers.get("Retry-After", 5))
        print(f"Rate limit hit for audio features batch. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        return get_audio_features_batch(access_token, track_ids)
    else:
        print(f"Failed to retrieve audio features batch: {response.status_code} - {response.text}")
        return []

# Step 5: Write track details with audio features to CSV
def write_tracks_to_csv(tracks):
    file_exists = os.path.isfile(track_file_path)
    with open(track_file_path, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        if not file_exists:
            writer.writerow([
                'artist_id', 'track_id', 'track_name', 'popularity', 'album_name', 
                'release_date', 'external_url', 'danceability', 'energy', 'key', 
                'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
                'liveness', 'valence', 'tempo'
            ])
        for track in tracks:
            writer.writerow([
                track['artist_id'],
                track['track_id'],
                track['track_name'],
                track['popularity'],
                track['album_name'],
                track['release_date'],
                track['external_url'],
                track.get('danceability'),
                track.get('energy'),
                track.get('key'),
                track.get('loudness'),
                track.get('mode'),
                track.get('speechiness'),
                track.get('acousticness'),
                track.get('instrumentalness'),
                track.get('liveness'),
                track.get('valence'),
                track.get('tempo')
            ])
    print(f"Wrote {len(tracks)} tracks to CSV.")

# Step 6: Main Function to Collect Top Tracks with Batched Audio Features
def collect_top_tracks_with_features(access_token, artist_ids, track_limit=5):
    total_tracks_collected = 0
    batch_track_data = []

    for artist_id in artist_ids:
        # Get the top tracks for the artist
        top_tracks = get_top_tracks(access_token, artist_id, limit=track_limit)
        
        # Structure the data without audio features for now
        for track in top_tracks:
            batch_track_data.append({
                'artist_id': artist_id,
                'track_id': track['id'],
                'track_name': track['name'],
                'popularity': track['popularity'],
                'album_name': track['album']['name'],
                'release_date': track['album']['release_date'],
                'external_url': track['external_urls']['spotify']
            })
        
        # When batch reaches 100 tracks, fetch audio features
        if len(batch_track_data) >= 100:
            # Collect track IDs and get audio features in bulk
            track_ids = [track['track_id'] for track in batch_track_data]
            audio_features = get_audio_features_batch(access_token, track_ids)
            
            # Add audio features to the track data
            for i, features in enumerate(audio_features):
                if features:  # Ensure audio features data is valid
                    batch_track_data[i].update(features)
            
            # Write batch to CSV
            write_tracks_to_csv(batch_track_data)
            total_tracks_collected += len(batch_track_data)
            batch_track_data = []  # Clear batch
            
            # Display progress
            print(f"Total tracks with audio features collected so far: {total_tracks_collected}")
        
        # Stop once we reach the limit, if specified
        if total_tracks_collected >= track_limit * len(artist_ids):
            break

    # Process any remaining tracks in the last batch
    if batch_track_data:
        track_ids = [track['track_id'] for track in batch_track_data]
        audio_features = get_audio_features_batch(access_token, track_ids)
        
        for i, features in enumerate(audio_features):
            if features:
                batch_track_data[i].update(features)
        
        write_tracks_to_csv(batch_track_data)
        total_tracks_collected += len(batch_track_data)
        print(f"Final batch written. Total tracks collected: {total_tracks_collected}")

# Run the collection process
if __name__ == "__main__":
    # Step 1: Get access token
    access_token = get_access_token(client_id, client_secret)
    
    # Step 2: Load artist IDs
    artist_ids = read_artist_ids(artist_file_path)
    
    # Step 3: Collect top tracks with batched audio features
    collect_top_tracks_with_features(access_token, artist_ids, track_limit=5)
# Out:
# Successfully obtained access token.
# Loaded 118000 artist IDs from file.
# Rate limit hit. Retrying in 32394 seconds.
