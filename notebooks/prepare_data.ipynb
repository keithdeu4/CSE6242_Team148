# %%
import pandas as pd
import sqlite3

# %%
artists = pd.read_csv("spotify_artists.csv")

# %%
conn = sqlite3.connect(r"C:\Users\seang\OneDrive\cse 6242\project\CSE6242_Team148\music_data.db")

# %%
artists_df = pd.read_sql_query("SELECT * FROM artists", conn)

# %%
artists.to_sql("artists", conn, if_exists="replace", index=False)
# Out:
# 197773

# %%
artists_df = pd.read_sql_query("SELECT * FROM artists", conn)

# %%
artists_df
# Out:
#                             id              name  popularity  followers  \
# 0       1LcaPN8JEgaie0AeMwMwf7          K.T.FROG           0          3
# 1       0N3h1pay1dHkET079RCjDb               KTF           0          3
# 2       3OX8yYPiXsw2f8JsFR5pir               KTF           0         12
# 3       0p99K5qeWoQdKlgViHkBal           Ktfcike           0          0
# 4       6hoI0BCzxRgZTp9n1A7SZL               KTF           0         11
# ...                        ...               ...         ...        ...
# 197768  1JEThk5QNpPoqQDZpVUcri       Madd Hyghts          17        146
# 197769  63ZJYWFEoWHVVDYhGLljFR   Middag Og Hygge          17         16
# 197770  2WgCTtmkGlo5NeSQWVp51S           Hyglyph           0        123
# 197771  1R5xnjgMVGlH1RHX4iyJ2i           HYGLYPH           0         23
# 197772  7GrQBZnSfsGN61MJo7DHCH  Hyggelige Covers          17         47
#
#        genres                                                url
# ...

# %%
songs = pd.read_csv("spotify_top_tracks.csv")

# %%
songs.to_sql("songs", conn, if_exists="replace", index=False)
# Out:
# 100566

# %%
songs
# Out:
#                      artist_id                track_id  \
# 0       1LcaPN8JEgaie0AeMwMwf7  3Ld9XCH0MoRLfF7SjYSAdR
# 1       1LcaPN8JEgaie0AeMwMwf7  3vzuslSBogxTy3cPagosdg
# 2       0N3h1pay1dHkET079RCjDb  3QQxapd6OhPx8DLeE43eeW
# 3       0N3h1pay1dHkET079RCjDb  1b6sBwwU9lhrUxuT9Ye0NR
# 4       0N3h1pay1dHkET079RCjDb  7fLzLxYylcfjzBDMoITdm4
# ...                        ...                     ...
# 100561  7G4d2oOEAsVGglC6CPFroy  0Got6T9vbWJfDW8SHSnPQh
# 100562  6hsPBNBejUSAMu7G6N3m15  4tmM2Mi14GTBg77fo94Z3b
# 100563  4baEU5qYuFaxWvvXFyhT8R  23OYh7VIlwrB0wp1rqzLLj
# 100564  4baEU5qYuFaxWvvXFyhT8R  4DylHIx2jzRiz8tnheXYel
# 100565  4baEU5qYuFaxWvvXFyhT8R  7IDSbcfeWzPFKTadwzs7PL
#
#                                            track_name  popularity  \
# 0                                        Steely Blues           0
# 1                                           ENKA Jazz           0
# 2                                                 RPG           0
# ...

# %%
audio_features = pd.read_csv("spotify_audio_features.csv")

# %%
audio_features.to_sql("audio_features", conn, if_exists="replace", index=False)
# Out:
# 100047

# %%
audio_features
# Out:
#                       track_id  danceability  energy  key  loudness  mode  \
# 0       3Ld9XCH0MoRLfF7SjYSAdR         0.668   0.670    7    -9.254     1
# 1       3vzuslSBogxTy3cPagosdg         0.605   0.743    9    -7.867     0
# 2       3QQxapd6OhPx8DLeE43eeW         0.668   0.640    7    -6.493     0
# 3       1b6sBwwU9lhrUxuT9Ye0NR         0.809   0.709    0    -6.167     1
# 4       7fLzLxYylcfjzBDMoITdm4         0.891   0.748    9    -6.923     1
# ...                        ...           ...     ...  ...       ...   ...
# 100042  5Oe392KdCPvGJKJTRNt2Y4         0.820   0.353    8   -11.695     0
# 100043  1bUAQF3u6CDHzHMhXAytw4         0.556   0.425   11    -4.946     1
# 100044  13vd9XlhG4LTeouje1UyTy         0.417   0.930    7    -4.192     0
# 100045  4zMblBnI0xXR5xhECcbfXB         0.642   0.858    3    -3.835     0
# 100046  2NS5qwgnrxAVPxQCqRblwU         0.784   0.475    7    -8.159     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
artist_profiles = artists.merge(songs,left_on="id",right_on="artist_id")

# %%
artist_profiles = artist_profiles.merge(audio_features,on="track_id")

# %%
artist_profiles.drop(columns="popularity_y",inplace=True)
artist_profiles.rename(columns={"popularity_x":"popularity"},inplace=True)

# %%
artist_profiles
# Out:
#                             id      name  popularity  followers genres  \
# 0       1LcaPN8JEgaie0AeMwMwf7  K.T.FROG           0          3    NaN
# 1       1LcaPN8JEgaie0AeMwMwf7  K.T.FROG           0          3    NaN
# 2       0N3h1pay1dHkET079RCjDb       KTF           0          3    NaN
# 3       0N3h1pay1dHkET079RCjDb       KTF           0          3    NaN
# 4       0N3h1pay1dHkET079RCjDb       KTF           0          3    NaN
# ...                        ...       ...         ...        ...    ...
# 167385  45HOFxqHRw9WNIbUZEgbkY    Hyghed          11        802    NaN
# 167386  45HOFxqHRw9WNIbUZEgbkY    Hyghed          11        802    NaN
# 167387  45HOFxqHRw9WNIbUZEgbkY    Hyghed          11        802    NaN
# 167388  45HOFxqHRw9WNIbUZEgbkY    Hyghed          11        802    NaN
# 167389  45HOFxqHRw9WNIbUZEgbkY    Hyghed          11        802    NaN
#
#                                                       url  \
# ...

# %%
def aggregate_artist_profiles(artist_profiles):
    # Select features to aggregate
    features = [
        "danceability",
        "energy",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "speechiness",
        "popularity",
    ]

    # Aggregate by artist
    artist_profiles = artist_profiles.groupby("artist_id")[features].mean().reset_index()

    # Reorder columns to have artist name first for easier readability
    artist_profiles = artist_profiles[["artist_id"] + features]

    return artist_profiles

# %%
artist_profiles = aggregate_artist_profiles(artist_profiles)

# %%
artist_profiles.to_sql("artist_profiles", conn, if_exists="replace", index=False)
# Out:
# 14638

# %%
conn.close()

# %%
artist_profiles
# Out:
#                     artist_id  danceability    energy  acousticness  \
# 0      001aJOc7CSQVo3XzoLG4DK      0.854300  0.534500      0.192914
# 1      00AZMeo9gIwohb6SoS3IPY      0.694500  0.804300      0.069430
# 2      00C6n2psbFm6XWqyPCXJ5v      0.516700  0.487800      0.394130
# 3      00D3xKrsFSzuaTFrIMFLF6      0.642800  0.632000      0.301740
# 4      00DQn2x4PUykmPHF8EVpYy      0.681200  0.488900      0.442700
# ...                       ...           ...       ...           ...
# 14633  7zr4aCX74Bf2O4yKhVaYKL      0.786500  0.837300      0.021524
# 14634  7zsPBvRIAprYciVh53ZekP      0.526300  0.404800      0.900900
# 14635  7zwJ09FAPbh7EJYvwEAqDD      0.705200  0.530900      0.744400
# 14636  7zxELyatnJcRUuictwdA26      0.795000  0.483000      0.064000
# 14637  7zzN5lEQF9MQnJySdQqHiN      0.573667  0.360333      0.230833
#
#        instrumentalness  liveness   valence  speechiness  popularity
# 0              0.027372  0.089220  0.586300      0.10318        46.0
# ...
